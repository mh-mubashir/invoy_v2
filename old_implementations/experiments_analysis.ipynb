# %% [markdown]
# # Invoy VLM Experiments \u2013 Analysis\n\nThis notebook is a starting point for analyzing activity tracking experiments stored in SQLite.\n\n## TODO\n- Load one or more `activity_*.db` files.\n- Compute latency distributions for `activity_inference_ms` and `change_inference_ms` by model and session.\n- After annotation, compute average `activity_quality_score` and `change_correct` rates.\n- Generate plots and tables suitable for inclusion in reports.\n
